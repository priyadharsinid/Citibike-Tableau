# %%
import pandas as pd
import numpy as np

# %%
cb01 = pd.read_csv("JC-202301-citibike-tripdata.csv")
cb02 = pd.read_csv("JC-202302-citibike-tripdata.csv")
cb03 =pd.read_csv("JC-202303-citibike-tripdata.csv")

# %%
cb = pd.concat([cb01,cb02,cb03])

cb.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  0905B18B365C9D20   classic_bike  2023-01-28 09:18:10  2023-01-28 09:28:52
# 1  B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12  2023-01-23 20:18:27
# 2  5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04  2023-01-29 15:32:38
# 3  E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08  2023-01-24 18:42:13
# 4  323165780CA0734B   classic_bike  2023-01-21 20:44:09  2023-01-21 20:48:08
#
#                          start_station_name start_station_id  \
# 0  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 1  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 2  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 3  Hoboken Terminal - Hudson St & Hudson Pl            HB101
# 4                             Hamilton Park            JC009
#
#                              end_station_name end_station_id  start_lat  \
# ...

# %%
cb.tail()
# Out:
#                 ride_id  rideable_type           started_at  \
# 63067  BF0032DA4A305161   classic_bike  2023-03-19 16:25:24
# 63068  32172F9BEF8D56A2   classic_bike  2023-03-22 16:14:15
# 63069  6FCF0C7C1E254341  electric_bike  2023-03-19 02:16:02
# 63070  34DFBEB02424B55E  electric_bike  2023-03-30 20:09:24
# 63071  A235AD010540ACA2   classic_bike  2023-03-17 17:53:28
#
#                   ended_at start_station_name start_station_id  \
# 63067  2023-03-19 16:33:20  Madison St & 1 St            HB402
# 63068  2023-03-22 16:20:28  Madison St & 1 St            HB402
# 63069  2023-03-19 02:21:15  Madison St & 1 St            HB402
# 63070  2023-03-30 20:15:08  Madison St & 1 St            HB402
# 63071  2023-03-17 17:59:43  Madison St & 1 St            HB402
#
#                         end_station_name end_station_id  start_lat  start_lng  \
# 63067  Columbus Park - Clinton St & 9 St          HB501   40.73879   -74.0393
# ...

# %%
cb.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
cb.describe()
# Out:
#            start_lat      start_lng        end_lat        end_lng
# count  170360.000000  170360.000000  170213.000000  170213.000000
# mean       40.732302     -74.040728      40.732203     -74.040387
# std         0.011876       0.012209       0.012022       0.012053
# min        40.706575     -74.086854      40.670000     -74.160000
# 25%        40.721525     -74.046305      40.721525     -74.045953
# 50%        40.735208     -74.038051      40.735208     -74.037977
# 75%        40.742258     -74.031046      40.742258     -74.030970
# max        40.754907     -74.023704      40.851680     -73.918975

# %%
cb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170360 entries, 0 to 63071
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             170360 non-null  object
#  1   rideable_type       170360 non-null  object
#  2   started_at          170360 non-null  object
#  3   ended_at            170360 non-null  object
#  4   start_station_name  170360 non-null  object
#  5   start_station_id    170360 non-null  object
#  6   end_station_name    169809 non-null  object
#  7   end_station_id      169809 non-null  object
#  8   start_lat           170360 non-null  float64
#  9   start_lng           170360 non-null  float64
#  10  end_lat             170213 non-null  float64
#  11  end_lng             170213 non-null  float64
#  12  member_casual       170360 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 18.2+ MB

# %%
cb.to_csv("cb.csv")
